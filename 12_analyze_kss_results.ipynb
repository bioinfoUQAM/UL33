# %%
import os
import sys
import ast
import json
sys.path.append('utils')
import utils

# %%
def calculate_variation_presence(data, input_position, input_kmer):
    """
    Calculate the percentage presence of a specific k-mer variation at a given position across different classes.

    Parameters:
    - data (dict): The data containing sequences and their associated classes.
    - input_position (tuple or str): The position to check. If a string, it will be converted to a tuple.
    - input_kmer (str): The k-mer variation to look for.

    Returns:
    - variation_percentages (dict): A dictionary with class IDs as keys and percentage presence as values.
    """
    # If input_position is a string, convert it to a tuple safely
    if isinstance(input_position, str):
        input_position = ast.literal_eval(input_position)
    
    class_counts = {}
    class_variation_counts = {}

    # Count occurrences and prepare data
    for gene_sequences in data.values():
        for seq_id, positions in gene_sequences.items():
            class_id = seq_id.split('|')[-1]
            class_counts.setdefault(class_id, {})
            class_variation_counts.setdefault(class_id, {})

            # Initialize counts if not present
            class_counts[class_id].setdefault(input_position, 0)
            class_variation_counts[class_id].setdefault(input_position, 0)

            # Convert keys to tuples for comparison
            for key_str, pos_data in positions.items():
                key_tuple = ast.literal_eval(key_str)

                # Check for matching position
                if input_position == key_tuple:
                    class_counts[class_id][input_position] += 1

                    # Check for matching k-mer variation
                    if pos_data['variations'] == input_kmer:
                        class_variation_counts[class_id][input_position] += 1

    # Calculate percentages
    variation_percentages = {}
    for class_id in class_counts:
        count = class_variation_counts[class_id][input_position]
        total = class_counts[class_id][input_position]
        percentage = (count / total) * 100 if total > 0 else 0
        variation_percentages[class_id] = percentage

    return variation_percentages

# %%
def get_top_n_scores(file_paths, score_index, top_n):
    """
    Retrieve the top N scores from given JSON files based on a specified score index.

    Parameters:
    - file_paths (list): List of paths to JSON files containing scores.
    - score_index (int): The index of the score to sort by in the scores list.
    - top_n (int): The number of top scores to retrieve.

    Returns:
    - list: A list of tuples containing (file_path, key, score) of the top N scores.
    """
    all_scores = []

    # Loop through each file and collect scores
    for json_file_path in file_paths:
        try:
            scores = utils.load_data_from_json(json_file_path)
            # Collect score tuples
            score_tuples = [
                (json_file_path, key, values[score_index])
                for key, values in scores.items()
                if isinstance(values, list) and len(values) > score_index
            ]
            all_scores.extend(score_tuples)
        except Exception as e:
            print(f"Error processing file {json_file_path}: {str(e)}")

    # Sort and retrieve top N scores
    sorted_scores = sorted(all_scores, key=lambda x: x[2], reverse=True)
    return sorted_scores[:top_n]

# %%
def process_dataset(name, score_index, n):
    """
    Process a single dataset to extract top N k-mer variations and their percentages.

    Parameters:
    - name (str): The name of the dataset.
    - score_index (int): The index of the score to sort by.
    - n (int): The number of top scores to retrieve.
    """
    print(f"\nProcessing: {name}")


    genes = [name]
    base_path = f"data/results"
    compiled_results_path = os.path.join(base_path, f"{name}_compiled_results.json")
    data_path = os.path.join(base_path, f"{name}_results.json")

    # Prepare file paths for score files
    file_paths = [os.path.join(base_path, f"{gene}_uncategorized_scores.json") for gene in genes]

    # Get top N scores
    top_n_scores = get_top_n_scores(file_paths, score_index, n)

    # Extract positions and associated genes
    positions = []
    for file_path, key, _ in top_n_scores:
        position_part = key.split(',', 1)[0][1:]  # Extract position
        gene = os.path.basename(file_path).split('_')[0]
        positions.append((position_part, gene, key))
    

    # Load compiled results and data once
    with open(compiled_results_path, 'r') as file:
        compiled_data = json.load(file)
    data = utils.load_data_from_json(data_path)

    # Collect k-mers and their variations
    k_mers_variations_dict = {}
    for position, gene, key_in_scores in positions:
        # Retrieve variations for the position
        gene_data = compiled_data.get(gene, {})
        for key, value in gene_data.items():
            current_position = key.split(',', 1)[0][1:]
            if current_position == position:
                k_mers_variations_dict[(key, gene)] = [value['variations'], value['amino_acid_changes']]

    # Print the results
    for (key, gene), variations in k_mers_variations_dict.items():
        for kmer in variations[0]:
            print(f"K-mer variations: {variations[0]}, Key: {key}, K-mer: {kmer}, Gene: {gene}")
            variation_percentages = calculate_variation_presence(data, key, kmer)
            print(f"Percentages of {kmer} at key {key}:")
            for class_id, percentage in variation_percentages.items():
                if percentage != 0:
                    print(f"  Class {class_id}: {percentage:.2f}%")
            print()

# %%
# Usage example
datasets = ['UL33']
score_index = 3  # Index of the score to sort by
n = 25  # Number of top scores to retrieve

for dataset_name in datasets:
    process_dataset(dataset_name, score_index, n)
# Out:
# Processing: UL33
# K-mer variations: ['ATCCGCACT', 'ATCCGCACC', 'ATTCGAACC', 'ATTCGCACC', 'ATCCGTACC'], Key: (91, 'ATCCGTACC'), K-mer: ATCCGCACT, Gene: UL33
# Percentages of ATCCGCACT at key (91, 'ATCCGTACC'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 0.79%
#
# K-mer variations: ['ATCCGCACT', 'ATCCGCACC', 'ATTCGAACC', 'ATTCGCACC', 'ATCCGTACC'], Key: (91, 'ATCCGTACC'), K-mer: ATCCGCACC, Gene: UL33
# Percentages of ATCCGCACC at key (91, 'ATCCGTACC'):
#   Class TOLEDO: 100.00%
#
# K-mer variations: ['ATCCGCACT', 'ATCCGCACC', 'ATTCGAACC', 'ATTCGCACC', 'ATCCGTACC'], Key: (91, 'ATCCGTACC'), K-mer: ATTCGAACC, Gene: UL33
# Percentages of ATTCGAACC at key (91, 'ATCCGTACC'):
#   Class AD169: 99.18%
#
# K-mer variations: ['ATCCGCACT', 'ATCCGCACC', 'ATTCGAACC', 'ATTCGCACC', 'ATCCGTACC'], Key: (91, 'ATCCGTACC'), K-mer: ATTCGCACC, Gene: UL33
# Percentages of ATTCGCACC at key (91, 'ATCCGTACC'):
#   Class C5: 100.00%
#
# K-mer variations: ['ATCCGCACT', 'ATCCGCACC', 'ATTCGAACC', 'ATTCGCACC', 'ATCCGTACC'], Key: (91, 'ATCCGTACC'), K-mer: ATCCGTACC, Gene: UL33
# Percentages of ATCCGTACC at key (91, 'ATCCGTACC'):
#   Class MERLIN: 99.21%
#   Class AD169: 0.82%
#
# K-mer variations: ['ACCAGCACC', 'ACT---CCT', 'ACCACTACT', 'ACCAGTACT', 'ACCGATACT'], Key: (37, 'ACCGATACT'), K-mer: ACCAGCACC, Gene: UL33
# Percentages of ACCAGCACC at key (37, 'ACCGATACT'):
#   Class C5: 100.00%
#
# K-mer variations: ['ACCAGCACC', 'ACT---CCT', 'ACCACTACT', 'ACCAGTACT', 'ACCGATACT'], Key: (37, 'ACCGATACT'), K-mer: ACT---CCT, Gene: UL33
# Percentages of ACT---CCT at key (37, 'ACCGATACT'):
#   Class AD169: 94.26%
#
# K-mer variations: ['ACCAGCACC', 'ACT---CCT', 'ACCACTACT', 'ACCAGTACT', 'ACCGATACT'], Key: (37, 'ACCGATACT'), K-mer: ACCACTACT, Gene: UL33
# Percentages of ACCACTACT at key (37, 'ACCGATACT'):
#   Class TOLEDO: 100.00%
#
# K-mer variations: ['ACCAGCACC', 'ACT---CCT', 'ACCACTACT', 'ACCAGTACT', 'ACCGATACT'], Key: (37, 'ACCGATACT'), K-mer: ACCAGTACT, Gene: UL33
# Percentages of ACCAGTACT at key (37, 'ACCGATACT'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 1.57%
#
# K-mer variations: ['ACCAGCACC', 'ACT---CCT', 'ACCACTACT', 'ACCAGTACT', 'ACCGATACT'], Key: (37, 'ACCGATACT'), K-mer: ACCGATACT, Gene: UL33
# Percentages of ACCGATACT at key (37, 'ACCGATACT'):
#   Class MERLIN: 98.43%
#
# K-mer variations: ['TCTTCGTGT', 'GCCTCGTGC', 'GCTTCGTGC', 'ACTTCGTGC', 'GCCTCGTGT'], Key: (307, 'GCTTCGTGC'), K-mer: TCTTCGTGT, Gene: UL33
# Percentages of TCTTCGTGT at key (307, 'GCTTCGTGC'):
#   Class C5: 100.00%
#
# K-mer variations: ['TCTTCGTGT', 'GCCTCGTGC', 'GCTTCGTGC', 'ACTTCGTGC', 'GCCTCGTGT'], Key: (307, 'GCTTCGTGC'), K-mer: GCCTCGTGC, Gene: UL33
# Percentages of GCCTCGTGC at key (307, 'GCTTCGTGC'):
#   Class AD169: 0.82%
#   Class TOLEDO: 97.70%
#
# K-mer variations: ['TCTTCGTGT', 'GCCTCGTGC', 'GCTTCGTGC', 'ACTTCGTGC', 'GCCTCGTGT'], Key: (307, 'GCTTCGTGC'), K-mer: GCTTCGTGC, Gene: UL33
# Percentages of GCTTCGTGC at key (307, 'GCTTCGTGC'):
#   Class MERLIN: 100.00%
#
# K-mer variations: ['TCTTCGTGT', 'GCCTCGTGC', 'GCTTCGTGC', 'ACTTCGTGC', 'GCCTCGTGT'], Key: (307, 'GCTTCGTGC'), K-mer: ACTTCGTGC, Gene: UL33
# Percentages of ACTTCGTGC at key (307, 'GCTTCGTGC'):
#   Class TOWNE: 100.00%
#
# K-mer variations: ['TCTTCGTGT', 'GCCTCGTGC', 'GCTTCGTGC', 'ACTTCGTGC', 'GCCTCGTGT'], Key: (307, 'GCTTCGTGC'), K-mer: GCCTCGTGT, Gene: UL33
# Percentages of GCCTCGTGT at key (307, 'GCTTCGTGC'):
#   Class AD169: 95.90%
#   Class TOLEDO: 2.30%
#
# K-mer variations: ['CAGTCGTAC', 'CAATCATAC', 'CAGTCATAC', 'CAGTCGTAT', 'CAATCGTAC'], Key: (424, 'CAGTCGTAC'), K-mer: CAGTCGTAC, Gene: UL33
# Percentages of CAGTCGTAC at key (424, 'CAGTCGTAC'):
#   Class MERLIN: 100.00%
#
# K-mer variations: ['CAGTCGTAC', 'CAATCATAC', 'CAGTCATAC', 'CAGTCGTAT', 'CAATCGTAC'], Key: (424, 'CAGTCGTAC'), K-mer: CAATCATAC, Gene: UL33
# Percentages of CAATCATAC at key (424, 'CAGTCGTAC'):
#   Class AD169: 100.00%
#
# K-mer variations: ['CAGTCGTAC', 'CAATCATAC', 'CAGTCATAC', 'CAGTCGTAT', 'CAATCGTAC'], Key: (424, 'CAGTCGTAC'), K-mer: CAGTCATAC, Gene: UL33
# Percentages of CAGTCATAC at key (424, 'CAGTCGTAC'):
#   Class C5: 100.00%
#
# K-mer variations: ['CAGTCGTAC', 'CAATCATAC', 'CAGTCATAC', 'CAGTCGTAT', 'CAATCGTAC'], Key: (424, 'CAGTCGTAC'), K-mer: CAGTCGTAT, Gene: UL33
# Percentages of CAGTCGTAT at key (424, 'CAGTCGTAC'):
#   Class TOWNE: 97.87%
#
# K-mer variations: ['CAGTCGTAC', 'CAATCATAC', 'CAGTCATAC', 'CAGTCGTAT', 'CAATCGTAC'], Key: (424, 'CAGTCGTAC'), K-mer: CAATCGTAC, Gene: UL33
# Percentages of CAATCGTAC at key (424, 'CAGTCGTAC'):
#   Class TOLEDO: 98.85%
#
# K-mer variations: ['AATGCCACT', 'AATACTAAT', 'AGTAGCAAT', 'AATACCAAC', 'AATACCAAT'], Key: (541, 'AGTAGCAAT'), K-mer: AATGCCACT, Gene: UL33
# Percentages of AATGCCACT at key (541, 'AGTAGCAAT'):
#   Class TOLEDO: 98.85%
#
# K-mer variations: ['AATGCCACT', 'AATACTAAT', 'AGTAGCAAT', 'AATACCAAC', 'AATACCAAT'], Key: (541, 'AGTAGCAAT'), K-mer: AATACTAAT, Gene: UL33
# Percentages of AATACTAAT at key (541, 'AGTAGCAAT'):
#   Class AD169: 98.36%
#
# K-mer variations: ['AATGCCACT', 'AATACTAAT', 'AGTAGCAAT', 'AATACCAAC', 'AATACCAAT'], Key: (541, 'AGTAGCAAT'), K-mer: AGTAGCAAT, Gene: UL33
# Percentages of AGTAGCAAT at key (541, 'AGTAGCAAT'):
#   Class MERLIN: 99.21%
#
# K-mer variations: ['AATGCCACT', 'AATACTAAT', 'AGTAGCAAT', 'AATACCAAC', 'AATACCAAT'], Key: (541, 'AGTAGCAAT'), K-mer: AATACCAAC, Gene: UL33
# Percentages of AATACCAAC at key (541, 'AGTAGCAAT'):
#   Class C5: 100.00%
#
# K-mer variations: ['AATGCCACT', 'AATACTAAT', 'AGTAGCAAT', 'AATACCAAC', 'AATACCAAT'], Key: (541, 'AGTAGCAAT'), K-mer: AATACCAAT, Gene: UL33
# Percentages of AATACCAAT at key (541, 'AGTAGCAAT'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 0.79%
#   Class AD169: 1.64%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['ACCGTGCTA', 'ACTGTGCTA', 'ACCGTACTG', 'ACCGTGCTG', 'ACCGTGTTA'], Key: (253, 'ACCGTACTG'), K-mer: ACCGTGCTA, Gene: UL33
# Percentages of ACCGTGCTA at key (253, 'ACCGTACTG'):
#   Class C5: 88.89%
#   Class AD169: 0.82%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['ACCGTGCTA', 'ACTGTGCTA', 'ACCGTACTG', 'ACCGTGCTG', 'ACCGTGTTA'], Key: (253, 'ACCGTACTG'), K-mer: ACTGTGCTA, Gene: UL33
# Percentages of ACTGTGCTA at key (253, 'ACCGTACTG'):
#   Class AD169: 98.36%
#
# K-mer variations: ['ACCGTGCTA', 'ACTGTGCTA', 'ACCGTACTG', 'ACCGTGCTG', 'ACCGTGTTA'], Key: (253, 'ACCGTACTG'), K-mer: ACCGTACTG, Gene: UL33
# Percentages of ACCGTACTG at key (253, 'ACCGTACTG'):
#   Class MERLIN: 91.34%
#
# K-mer variations: ['ACCGTGCTA', 'ACTGTGCTA', 'ACCGTACTG', 'ACCGTGCTG', 'ACCGTGTTA'], Key: (253, 'ACCGTACTG'), K-mer: ACCGTGCTG, Gene: UL33
# Percentages of ACCGTGCTG at key (253, 'ACCGTACTG'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 0.79%
#
# K-mer variations: ['ACCGTGCTA', 'ACTGTGCTA', 'ACCGTACTG', 'ACCGTGCTG', 'ACCGTGTTA'], Key: (253, 'ACCGTACTG'), K-mer: ACCGTGTTA, Gene: UL33
# Percentages of ACCGTGTTA at key (253, 'ACCGTACTG'):
#   Class TOLEDO: 98.85%
#
# K-mer variations: ['GAT---GAA', 'AATGATATCAAT', 'AATGATACCACT', 'AACGATACCAAT', 'GAT---GAG', 'AATGGACAA'], Key: (532, 'AATGGACAA'), K-mer: GAT---GAA, Gene: UL33
# Percentages of GAT---GAA at key (532, 'AATGGACAA'):
#   Class TOWNE: 65.96%
#
# K-mer variations: ['GAT---GAA', 'AATGATATCAAT', 'AATGATACCACT', 'AACGATACCAAT', 'GAT---GAG', 'AATGGACAA'], Key: (532, 'AATGGACAA'), K-mer: AATGATATCAAT, Gene: UL33
# Percentages of AATGATATCAAT at key (532, 'AATGGACAA'):
#   Class C5: 88.89%
#
# K-mer variations: ['GAT---GAA', 'AATGATATCAAT', 'AATGATACCACT', 'AACGATACCAAT', 'GAT---GAG', 'AATGGACAA'], Key: (532, 'AATGGACAA'), K-mer: AATGATACCACT, Gene: UL33
# Percentages of AATGATACCACT at key (532, 'AATGGACAA'):
#   Class TOLEDO: 91.95%
#
# K-mer variations: ['GAT---GAA', 'AATGATATCAAT', 'AATGATACCACT', 'AACGATACCAAT', 'GAT---GAG', 'AATGGACAA'], Key: (532, 'AATGGACAA'), K-mer: AACGATACCAAT, Gene: UL33
# Percentages of AACGATACCAAT at key (532, 'AATGGACAA'):
#   Class AD169: 95.08%
#
# K-mer variations: ['GAT---GAA', 'AATGATATCAAT', 'AATGATACCACT', 'AACGATACCAAT', 'GAT---GAG', 'AATGGACAA'], Key: (532, 'AATGGACAA'), K-mer: GAT---GAG, Gene: UL33
# Percentages of GAT---GAG at key (532, 'AATGGACAA'):
#   Class TOWNE: 29.79%
#
# K-mer variations: ['GAT---GAA', 'AATGATATCAAT', 'AATGATACCACT', 'AACGATACCAAT', 'GAT---GAG', 'AATGGACAA'], Key: (532, 'AATGGACAA'), K-mer: AATGGACAA, Gene: UL33
# Percentages of AATGGACAA at key (532, 'AATGGACAA'):
#   Class MERLIN: 99.21%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['ACATGGCTA', 'ACTTGGTTT', 'ACATGGCTC', 'ACTTGGCTT', 'ACCTGGTTT'], Key: (460, 'ACCTGGTTT'), K-mer: ACATGGCTA, Gene: UL33
# Percentages of ACATGGCTA at key (460, 'ACCTGGTTT'):
#   Class TOLEDO: 72.41%
#
# K-mer variations: ['ACATGGCTA', 'ACTTGGTTT', 'ACATGGCTC', 'ACTTGGCTT', 'ACCTGGTTT'], Key: (460, 'ACCTGGTTT'), K-mer: ACTTGGTTT, Gene: UL33
# Percentages of ACTTGGTTT at key (460, 'ACCTGGTTT'):
#   Class TOWNE: 100.00%
#
# K-mer variations: ['ACATGGCTA', 'ACTTGGTTT', 'ACATGGCTC', 'ACTTGGCTT', 'ACCTGGTTT'], Key: (460, 'ACCTGGTTT'), K-mer: ACATGGCTC, Gene: UL33
# Percentages of ACATGGCTC at key (460, 'ACCTGGTTT'):
#   Class AD169: 100.00%
#   Class TOLEDO: 27.59%
#
# K-mer variations: ['ACATGGCTA', 'ACTTGGTTT', 'ACATGGCTC', 'ACTTGGCTT', 'ACCTGGTTT'], Key: (460, 'ACCTGGTTT'), K-mer: ACTTGGCTT, Gene: UL33
# Percentages of ACTTGGCTT at key (460, 'ACCTGGTTT'):
#   Class C5: 100.00%
#
# K-mer variations: ['ACATGGCTA', 'ACTTGGTTT', 'ACATGGCTC', 'ACTTGGCTT', 'ACCTGGTTT'], Key: (460, 'ACCTGGTTT'), K-mer: ACCTGGTTT, Gene: UL33
# Percentages of ACCTGGTTT at key (460, 'ACCTGGTTT'):
#   Class MERLIN: 100.00%
#
# K-mer variations: ['CCATTTATC', 'CCCTTCATT', 'CCCTTTATC', 'CCTTTTATC', 'CCCTTCATC'], Key: (262, 'CCATTTATC'), K-mer: CCATTTATC, Gene: UL33
# Percentages of CCATTTATC at key (262, 'CCATTTATC'):
#   Class MERLIN: 99.21%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['CCATTTATC', 'CCCTTCATT', 'CCCTTTATC', 'CCTTTTATC', 'CCCTTCATC'], Key: (262, 'CCATTTATC'), K-mer: CCCTTCATT, Gene: UL33
# Percentages of CCCTTCATT at key (262, 'CCATTTATC'):
#   Class C5: 100.00%
#
# K-mer variations: ['CCATTTATC', 'CCCTTCATT', 'CCCTTTATC', 'CCTTTTATC', 'CCCTTCATC'], Key: (262, 'CCATTTATC'), K-mer: CCCTTTATC, Gene: UL33
# Percentages of CCCTTTATC at key (262, 'CCATTTATC'):
#   Class MERLIN: 0.79%
#   Class AD169: 100.00%
#   Class TOLEDO: 25.29%
#
# K-mer variations: ['CCATTTATC', 'CCCTTCATT', 'CCCTTTATC', 'CCTTTTATC', 'CCCTTCATC'], Key: (262, 'CCATTTATC'), K-mer: CCTTTTATC, Gene: UL33
# Percentages of CCTTTTATC at key (262, 'CCATTTATC'):
#   Class TOLEDO: 73.56%
#
# K-mer variations: ['CCATTTATC', 'CCCTTCATT', 'CCCTTTATC', 'CCTTTTATC', 'CCCTTCATC'], Key: (262, 'CCATTTATC'), K-mer: CCCTTCATC, Gene: UL33
# Percentages of CCCTTCATC at key (262, 'CCATTTATC'):
#   Class TOWNE: 100.00%
#
# K-mer variations: ['CGCAACAAC', 'AACCGCAGT', 'ATCCGCAAT', 'AATCGCAGT', '---CGCAAC'], Key: (28, 'AACCGCAGT'), K-mer: CGCAACAAC, Gene: UL33
# Percentages of CGCAACAAC at key (28, 'AACCGCAGT'):
#   Class AD169: 93.44%
#
# K-mer variations: ['CGCAACAAC', 'AACCGCAGT', 'ATCCGCAAT', 'AATCGCAGT', '---CGCAAC'], Key: (28, 'AACCGCAGT'), K-mer: AACCGCAGT, Gene: UL33
# Percentages of AACCGCAGT at key (28, 'AACCGCAGT'):
#   Class TOWNE: 29.79%
#   Class MERLIN: 99.21%
#
# K-mer variations: ['CGCAACAAC', 'AACCGCAGT', 'ATCCGCAAT', 'AATCGCAGT', '---CGCAAC'], Key: (28, 'AACCGCAGT'), K-mer: ATCCGCAAT, Gene: UL33
# Percentages of ATCCGCAAT at key (28, 'AACCGCAGT'):
#   Class C5: 100.00%
#
# K-mer variations: ['CGCAACAAC', 'AACCGCAGT', 'ATCCGCAAT', 'AATCGCAGT', '---CGCAAC'], Key: (28, 'AACCGCAGT'), K-mer: AATCGCAGT, Gene: UL33
# Percentages of AATCGCAGT at key (28, 'AACCGCAGT'):
#   Class TOWNE: 70.21%
#   Class MERLIN: 0.79%
#
# K-mer variations: ['CGCAACAAC', 'AACCGCAGT', 'ATCCGCAAT', 'AATCGCAGT', '---CGCAAC'], Key: (28, 'AACCGCAGT'), K-mer: ---CGCAAC, Gene: UL33
# Percentages of ---CGCAAC at key (28, 'AACCGCAGT'):
#   Class TOLEDO: 90.80%
#
# K-mer variations: ['CGATACCGT', 'CGATACCGC', 'CGTTATCGC', 'CGCTATCGC', 'CGTTACCGC'], Key: (388, 'CGATACCGC'), K-mer: CGATACCGT, Gene: UL33
# Percentages of CGATACCGT at key (388, 'CGATACCGC'):
#   Class TOWNE: 29.79%
#
# K-mer variations: ['CGATACCGT', 'CGATACCGC', 'CGTTATCGC', 'CGCTATCGC', 'CGTTACCGC'], Key: (388, 'CGATACCGC'), K-mer: CGATACCGC, Gene: UL33
# Percentages of CGATACCGC at key (388, 'CGATACCGC'):
#   Class TOWNE: 70.21%
#   Class MERLIN: 100.00%
#
# K-mer variations: ['CGATACCGT', 'CGATACCGC', 'CGTTATCGC', 'CGCTATCGC', 'CGTTACCGC'], Key: (388, 'CGATACCGC'), K-mer: CGTTATCGC, Gene: UL33
# Percentages of CGTTATCGC at key (388, 'CGATACCGC'):
#   Class AD169: 100.00%
#
# K-mer variations: ['CGATACCGT', 'CGATACCGC', 'CGTTATCGC', 'CGCTATCGC', 'CGTTACCGC'], Key: (388, 'CGATACCGC'), K-mer: CGCTATCGC, Gene: UL33
# Percentages of CGCTATCGC at key (388, 'CGATACCGC'):
#   Class TOLEDO: 100.00%
#
# K-mer variations: ['CGATACCGT', 'CGATACCGC', 'CGTTATCGC', 'CGCTATCGC', 'CGTTACCGC'], Key: (388, 'CGATACCGC'), K-mer: CGTTACCGC, Gene: UL33
# Percentages of CGTTACCGC at key (388, 'CGATACCGC'):
#   Class C5: 100.00%
#
# K-mer variations: ['GTACTCAGC', 'GTGCTGAGC', 'GTGCTCAGC', 'GTGTTGAGC'], Key: (271, 'GTGCTGAGC'), K-mer: GTACTCAGC, Gene: UL33
# Percentages of GTACTCAGC at key (271, 'GTGCTGAGC'):
#   Class AD169: 96.72%
#
# K-mer variations: ['GTACTCAGC', 'GTGCTGAGC', 'GTGCTCAGC', 'GTGTTGAGC'], Key: (271, 'GTGCTGAGC'), K-mer: GTGCTGAGC, Gene: UL33
# Percentages of GTGCTGAGC at key (271, 'GTGCTGAGC'):
#   Class C5: 77.78%
#   Class MERLIN: 100.00%
#
# K-mer variations: ['GTACTCAGC', 'GTGCTGAGC', 'GTGCTCAGC', 'GTGTTGAGC'], Key: (271, 'GTGCTGAGC'), K-mer: GTGCTCAGC, Gene: UL33
# Percentages of GTGCTCAGC at key (271, 'GTGCTGAGC'):
#   Class AD169: 1.64%
#   Class TOLEDO: 100.00%
#
# K-mer variations: ['GTACTCAGC', 'GTGCTGAGC', 'GTGCTCAGC', 'GTGTTGAGC'], Key: (271, 'GTGCTGAGC'), K-mer: GTGTTGAGC, Gene: UL33
# Percentages of GTGTTGAGC at key (271, 'GTGCTGAGC'):
#   Class TOWNE: 100.00%
#
# K-mer variations: ['CGCTTGGTT', 'CGTGTGGTG', 'CGCCTGGTA', 'CGCCTGGTT'], Key: (874, 'CGCCTGGTA'), K-mer: CGCTTGGTT, Gene: UL33
# Percentages of CGCTTGGTT at key (874, 'CGCCTGGTA'):
#   Class C5: 100.00%
#
# K-mer variations: ['CGCTTGGTT', 'CGTGTGGTG', 'CGCCTGGTA', 'CGCCTGGTT'], Key: (874, 'CGCCTGGTA'), K-mer: CGTGTGGTG, Gene: UL33
# Percentages of CGTGTGGTG at key (874, 'CGCCTGGTA'):
#   Class AD169: 99.18%
#
# K-mer variations: ['CGCTTGGTT', 'CGTGTGGTG', 'CGCCTGGTA', 'CGCCTGGTT'], Key: (874, 'CGCCTGGTA'), K-mer: CGCCTGGTA, Gene: UL33
# Percentages of CGCCTGGTA at key (874, 'CGCCTGGTA'):
#   Class TOWNE: 76.60%
#   Class MERLIN: 100.00%
#   Class TOLEDO: 2.30%
#
# K-mer variations: ['CGCTTGGTT', 'CGTGTGGTG', 'CGCCTGGTA', 'CGCCTGGTT'], Key: (874, 'CGCCTGGTA'), K-mer: CGCCTGGTT, Gene: UL33
# Percentages of CGCCTGGTT at key (874, 'CGCCTGGTA'):
#   Class TOLEDO: 97.70%
#
# K-mer variations: ['ACGGGGCCG', 'ACGGAGCCG', 'ACAGGGCCG', 'ACGGAGACG', 'ACTGAGCCG'], Key: (73, 'ACGGAGCCG'), K-mer: ACGGGGCCG, Gene: UL33
# Percentages of ACGGGGCCG at key (73, 'ACGGAGCCG'):
#   Class MERLIN: 0.79%
#   Class AD169: 0.82%
#   Class TOLEDO: 97.70%
#
# K-mer variations: ['ACGGGGCCG', 'ACGGAGCCG', 'ACAGGGCCG', 'ACGGAGACG', 'ACTGAGCCG'], Key: (73, 'ACGGAGCCG'), K-mer: ACGGAGCCG, Gene: UL33
# Percentages of ACGGAGCCG at key (73, 'ACGGAGCCG'):
#   Class TOWNE: 74.47%
#   Class MERLIN: 99.21%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['ACGGGGCCG', 'ACGGAGCCG', 'ACAGGGCCG', 'ACGGAGACG', 'ACTGAGCCG'], Key: (73, 'ACGGAGCCG'), K-mer: ACAGGGCCG, Gene: UL33
# Percentages of ACAGGGCCG at key (73, 'ACGGAGCCG'):
#   Class AD169: 99.18%
#
# K-mer variations: ['ACGGGGCCG', 'ACGGAGCCG', 'ACAGGGCCG', 'ACGGAGACG', 'ACTGAGCCG'], Key: (73, 'ACGGAGCCG'), K-mer: ACGGAGACG, Gene: UL33
# Percentages of ACGGAGACG at key (73, 'ACGGAGCCG'):
#   Class TOWNE: 25.53%
#
# K-mer variations: ['ACGGGGCCG', 'ACGGAGCCG', 'ACAGGGCCG', 'ACGGAGACG', 'ACTGAGCCG'], Key: (73, 'ACGGAGCCG'), K-mer: ACTGAGCCG, Gene: UL33
# Percentages of ACTGAGCCG at key (73, 'ACGGAGCCG'):
#   Class C5: 100.00%
#
# K-mer variations: ['ATAGCCGAC', 'ATAGCCGAT', 'GTGGCCGAC', 'GTAGCTGAA'], Key: (577, 'ATAGCCGAC'), K-mer: ATAGCCGAC, Gene: UL33
# Percentages of ATAGCCGAC at key (577, 'ATAGCCGAC'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 100.00%
#
# K-mer variations: ['ATAGCCGAC', 'ATAGCCGAT', 'GTGGCCGAC', 'GTAGCTGAA'], Key: (577, 'ATAGCCGAC'), K-mer: ATAGCCGAT, Gene: UL33
# Percentages of ATAGCCGAT at key (577, 'ATAGCCGAC'):
#   Class C5: 100.00%
#
# K-mer variations: ['ATAGCCGAC', 'ATAGCCGAT', 'GTGGCCGAC', 'GTAGCTGAA'], Key: (577, 'ATAGCCGAC'), K-mer: GTGGCCGAC, Gene: UL33
# Percentages of GTGGCCGAC at key (577, 'ATAGCCGAC'):
#   Class TOLEDO: 100.00%
#
# K-mer variations: ['ATAGCCGAC', 'ATAGCCGAT', 'GTGGCCGAC', 'GTAGCTGAA'], Key: (577, 'ATAGCCGAC'), K-mer: GTAGCTGAA, Gene: UL33
# Percentages of GTAGCTGAA at key (577, 'ATAGCCGAC'):
#   Class AD169: 91.80%
#
# K-mer variations: ['ACGCTGTCA', 'ACACTGGCA', 'ACGCTGGCA', 'ACGCTGGCG'], Key: (865, 'ACGCTGTCA'), K-mer: ACGCTGTCA, Gene: UL33
# Percentages of ACGCTGTCA at key (865, 'ACGCTGTCA'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 100.00%
#
# K-mer variations: ['ACGCTGTCA', 'ACACTGGCA', 'ACGCTGGCA', 'ACGCTGGCG'], Key: (865, 'ACGCTGTCA'), K-mer: ACACTGGCA, Gene: UL33
# Percentages of ACACTGGCA at key (865, 'ACGCTGTCA'):
#   Class C5: 100.00%
#
# K-mer variations: ['ACGCTGTCA', 'ACACTGGCA', 'ACGCTGGCA', 'ACGCTGGCG'], Key: (865, 'ACGCTGTCA'), K-mer: ACGCTGGCA, Gene: UL33
# Percentages of ACGCTGGCA at key (865, 'ACGCTGTCA'):
#   Class TOLEDO: 98.85%
#
# K-mer variations: ['ACGCTGTCA', 'ACACTGGCA', 'ACGCTGGCA', 'ACGCTGGCG'], Key: (865, 'ACGCTGTCA'), K-mer: ACGCTGGCG, Gene: UL33
# Percentages of ACGCTGGCG at key (865, 'ACGCTGTCA'):
#   Class AD169: 100.00%
#
# K-mer variations: ['ACCACGGTG', 'ACTACAGTA', 'ACTACGGTA', 'ACCACCGTG'], Key: (505, 'ACTACAGTA'), K-mer: ACCACGGTG, Gene: UL33
# Percentages of ACCACGGTG at key (505, 'ACTACAGTA'):
#   Class AD169: 99.18%
#
# K-mer variations: ['ACCACGGTG', 'ACTACAGTA', 'ACTACGGTA', 'ACCACCGTG'], Key: (505, 'ACTACAGTA'), K-mer: ACTACAGTA, Gene: UL33
# Percentages of ACTACAGTA at key (505, 'ACTACAGTA'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 100.00%
#
# K-mer variations: ['ACCACGGTG', 'ACTACAGTA', 'ACTACGGTA', 'ACCACCGTG'], Key: (505, 'ACTACAGTA'), K-mer: ACTACGGTA, Gene: UL33
# Percentages of ACTACGGTA at key (505, 'ACTACAGTA'):
#   Class TOLEDO: 97.70%
#
# K-mer variations: ['ACCACGGTG', 'ACTACAGTA', 'ACTACGGTA', 'ACCACCGTG'], Key: (505, 'ACTACAGTA'), K-mer: ACCACCGTG, Gene: UL33
# Percentages of ACCACCGTG at key (505, 'ACTACAGTA'):
#   Class C5: 100.00%
#
# K-mer variations: ['GTGATGCAT', 'GTAATGCAT', 'GTGATACAT', 'GTAATACAC'], Key: (514, 'GTGATACAT'), K-mer: GTGATGCAT, Gene: UL33
# Percentages of GTGATGCAT at key (514, 'GTGATACAT'):
#   Class AD169: 100.00%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['GTGATGCAT', 'GTAATGCAT', 'GTGATACAT', 'GTAATACAC'], Key: (514, 'GTGATACAT'), K-mer: GTAATGCAT, Gene: UL33
# Percentages of GTAATGCAT at key (514, 'GTGATACAT'):
#   Class TOLEDO: 98.85%
#
# K-mer variations: ['GTGATGCAT', 'GTAATGCAT', 'GTGATACAT', 'GTAATACAC'], Key: (514, 'GTGATACAT'), K-mer: GTGATACAT, Gene: UL33
# Percentages of GTGATACAT at key (514, 'GTGATACAT'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 100.00%
#
# K-mer variations: ['GTGATGCAT', 'GTAATGCAT', 'GTGATACAT', 'GTAATACAC'], Key: (514, 'GTGATACAT'), K-mer: GTAATACAC, Gene: UL33
# Percentages of GTAATACAC at key (514, 'GTGATACAT'):
#   Class C5: 100.00%
#
# K-mer variations: ['CTCAACGCT', 'CTCAATGCC', 'CTTAACGCC', 'CTTAACGCT'], Key: (145, 'CTCAATGCC'), K-mer: CTCAACGCT, Gene: UL33
# Percentages of CTCAACGCT at key (145, 'CTCAATGCC'):
#   Class TOLEDO: 98.85%
#
# K-mer variations: ['CTCAACGCT', 'CTCAATGCC', 'CTTAACGCC', 'CTTAACGCT'], Key: (145, 'CTCAATGCC'), K-mer: CTCAATGCC, Gene: UL33
# Percentages of CTCAATGCC at key (145, 'CTCAATGCC'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 100.00%
#
# K-mer variations: ['CTCAACGCT', 'CTCAATGCC', 'CTTAACGCC', 'CTTAACGCT'], Key: (145, 'CTCAATGCC'), K-mer: CTTAACGCC, Gene: UL33
# Percentages of CTTAACGCC at key (145, 'CTCAATGCC'):
#   Class AD169: 97.54%
#
# K-mer variations: ['CTCAACGCT', 'CTCAATGCC', 'CTTAACGCC', 'CTTAACGCT'], Key: (145, 'CTCAATGCC'), K-mer: CTTAACGCT, Gene: UL33
# Percentages of CTTAACGCT at key (145, 'CTCAATGCC'):
#   Class C5: 100.00%
#
# K-mer variations: ['TCGGTGGTT', 'TCGGTGATT', 'TCGGTGATC', 'TCGGTAATT'], Key: (325, 'TCGGTGATT'), K-mer: TCGGTGGTT, Gene: UL33
# Percentages of TCGGTGGTT at key (325, 'TCGGTGATT'):
#   Class C5: 100.00%
#
# K-mer variations: ['TCGGTGGTT', 'TCGGTGATT', 'TCGGTGATC', 'TCGGTAATT'], Key: (325, 'TCGGTGATT'), K-mer: TCGGTGATT, Gene: UL33
# Percentages of TCGGTGATT at key (325, 'TCGGTGATT'):
#   Class MERLIN: 100.00%
#   Class AD169: 0.82%
#
# K-mer variations: ['TCGGTGGTT', 'TCGGTGATT', 'TCGGTGATC', 'TCGGTAATT'], Key: (325, 'TCGGTGATT'), K-mer: TCGGTGATC, Gene: UL33
# Percentages of TCGGTGATC at key (325, 'TCGGTGATT'):
#   Class AD169: 99.18%
#   Class TOLEDO: 96.55%
#
# K-mer variations: ['TCGGTGGTT', 'TCGGTGATT', 'TCGGTGATC', 'TCGGTAATT'], Key: (325, 'TCGGTGATT'), K-mer: TCGGTAATT, Gene: UL33
# Percentages of TCGGTAATT at key (325, 'TCGGTGATT'):
#   Class TOWNE: 100.00%
#
# K-mer variations: ['GCGCTCATT', 'ACACTCATC', 'ACATTCATC', 'ACGTTCATC'], Key: (118, 'ACGTTCATC'), K-mer: GCGCTCATT, Gene: UL33
# Percentages of GCGCTCATT at key (118, 'ACGTTCATC'):
#   Class C5: 100.00%
#
# K-mer variations: ['GCGCTCATT', 'ACACTCATC', 'ACATTCATC', 'ACGTTCATC'], Key: (118, 'ACGTTCATC'), K-mer: ACACTCATC, Gene: UL33
# Percentages of ACACTCATC at key (118, 'ACGTTCATC'):
#   Class TOLEDO: 89.66%
#
# K-mer variations: ['GCGCTCATT', 'ACACTCATC', 'ACATTCATC', 'ACGTTCATC'], Key: (118, 'ACGTTCATC'), K-mer: ACATTCATC, Gene: UL33
# Percentages of ACATTCATC at key (118, 'ACGTTCATC'):
#   Class TOWNE: 70.21%
#   Class MERLIN: 0.79%
#   Class AD169: 97.54%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['GCGCTCATT', 'ACACTCATC', 'ACATTCATC', 'ACGTTCATC'], Key: (118, 'ACGTTCATC'), K-mer: ACGTTCATC, Gene: UL33
# Percentages of ACGTTCATC at key (118, 'ACGTTCATC'):
#   Class TOWNE: 29.79%
#   Class MERLIN: 99.21%
#
# K-mer variations: ['TATATGATT', 'TATACAATT', 'TATATAATT', 'TACATAGTT'], Key: (442, 'TATATAATT'), K-mer: TATATGATT, Gene: UL33
# Percentages of TATATGATT at key (442, 'TATATAATT'):
#   Class AD169: 89.34%
#
# K-mer variations: ['TATATGATT', 'TATACAATT', 'TATATAATT', 'TACATAGTT'], Key: (442, 'TATATAATT'), K-mer: TATACAATT, Gene: UL33
# Percentages of TATACAATT at key (442, 'TATATAATT'):
#   Class TOLEDO: 98.85%
#
# K-mer variations: ['TATATGATT', 'TATACAATT', 'TATATAATT', 'TACATAGTT'], Key: (442, 'TATATAATT'), K-mer: TATATAATT, Gene: UL33
# Percentages of TATATAATT at key (442, 'TATATAATT'):
#   Class TOWNE: 97.87%
#   Class MERLIN: 100.00%
#   Class AD169: 8.20%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['TATATGATT', 'TATACAATT', 'TATATAATT', 'TACATAGTT'], Key: (442, 'TATATAATT'), K-mer: TACATAGTT, Gene: UL33
# Percentages of TACATAGTT at key (442, 'TATATAATT'):
#   Class C5: 100.00%
#
# K-mer variations: ['CACGAAGCT', 'CATGAAGCC', 'AATGGTACA', 'CACGATGCC'], Key: (523, 'AATGGTACA'), K-mer: CACGAAGCT, Gene: UL33
# Percentages of CACGAAGCT at key (523, 'AATGGTACA'):
#   Class C5: 88.89%
#
# K-mer variations: ['CACGAAGCT', 'CATGAAGCC', 'AATGGTACA', 'CACGATGCC'], Key: (523, 'AATGGTACA'), K-mer: CATGAAGCC, Gene: UL33
# Percentages of CATGAAGCC at key (523, 'AATGGTACA'):
#   Class TOLEDO: 100.00%
#
# K-mer variations: ['CACGAAGCT', 'CATGAAGCC', 'AATGGTACA', 'CACGATGCC'], Key: (523, 'AATGGTACA'), K-mer: AATGGTACA, Gene: UL33
# Percentages of AATGGTACA at key (523, 'AATGGTACA'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 99.21%
#
# K-mer variations: ['CACGAAGCT', 'CATGAAGCC', 'AATGGTACA', 'CACGATGCC'], Key: (523, 'AATGGTACA'), K-mer: CACGATGCC, Gene: UL33
# Percentages of CACGATGCC at key (523, 'AATGGTACA'):
#   Class AD169: 97.54%
#
# K-mer variations: ['AATGACACT', 'AACAGCACC', 'AACAGTACC', 'AACATCACC'], Key: (55, 'AACATCACC'), K-mer: AATGACACT, Gene: UL33
# Percentages of AATGACACT at key (55, 'AACATCACC'):
#   Class MERLIN: 0.79%
#   Class AD169: 100.00%
#   Class TOLEDO: 100.00%
#
# K-mer variations: ['AATGACACT', 'AACAGCACC', 'AACAGTACC', 'AACATCACC'], Key: (55, 'AACATCACC'), K-mer: AACAGCACC, Gene: UL33
# Percentages of AACAGCACC at key (55, 'AACATCACC'):
#   Class C5: 100.00%
#
# K-mer variations: ['AATGACACT', 'AACAGCACC', 'AACAGTACC', 'AACATCACC'], Key: (55, 'AACATCACC'), K-mer: AACAGTACC, Gene: UL33
# Percentages of AACAGTACC at key (55, 'AACATCACC'):
#   Class TOWNE: 100.00%
#   Class MERLIN: 0.79%
#
# K-mer variations: ['AATGACACT', 'AACAGCACC', 'AACAGTACC', 'AACATCACC'], Key: (55, 'AACATCACC'), K-mer: AACATCACC, Gene: UL33
# Percentages of AACATCACC at key (55, 'AACATCACC'):
#   Class MERLIN: 98.43%
#
# K-mer variations: ['TCTCAAAAA', 'TCTCAGAAA', 'TCACAGAAA', 'TCACAAAAA'], Key: (703, 'TCTCAAAAA'), K-mer: TCTCAAAAA, Gene: UL33
# Percentages of TCTCAAAAA at key (703, 'TCTCAAAAA'):
#   Class C5: 22.22%
#   Class TOWNE: 2.13%
#   Class MERLIN: 92.91%
#
# K-mer variations: ['TCTCAAAAA', 'TCTCAGAAA', 'TCACAGAAA', 'TCACAAAAA'], Key: (703, 'TCTCAAAAA'), K-mer: TCTCAGAAA, Gene: UL33
# Percentages of TCTCAGAAA at key (703, 'TCTCAAAAA'):
#   Class C5: 77.78%
#   Class TOWNE: 97.87%
#   Class MERLIN: 7.09%
#
# K-mer variations: ['TCTCAAAAA', 'TCTCAGAAA', 'TCACAGAAA', 'TCACAAAAA'], Key: (703, 'TCTCAAAAA'), K-mer: TCACAGAAA, Gene: UL33
# Percentages of TCACAGAAA at key (703, 'TCTCAAAAA'):
#   Class AD169: 98.36%
#   Class TOLEDO: 1.15%
#
# K-mer variations: ['TCTCAAAAA', 'TCTCAGAAA', 'TCACAGAAA', 'TCACAAAAA'], Key: (703, 'TCTCAAAAA'), K-mer: TCACAAAAA, Gene: UL33
# Percentages of TCACAAAAA at key (703, 'TCTCAAAAA'):
#   Class AD169: 0.82%
#   Class TOLEDO: 98.85%
